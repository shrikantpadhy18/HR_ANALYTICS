# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# %%
df=pd.read_csv("C:\\Users\\shrikant padhy\\Desktop\\codebasics\\py\\ML\\7_logistic_reg\\Exercise\\HR_comma_sep.csv")

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
df.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years Department salary
# 14994                      0    support    low
# 14995                      0    support    low
# 14996                      0    support    low
# ...

# %%
plt.scatter(df['number_project'],df['left'],marker='+')

# %%
plt.plot(df['number_project'],df['left'])
plt.show()

# %% [markdown]
# # Factors affecting Employee retention and employees leaving the firm

# %%
left=df[df.left==1]

# %%
left
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
len(left)
# Out:
# 3571

# %%
retained=df[df.left==0]

# %%
retained
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2001                 0.82             0.67               2
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2004                 0.49             0.60               3
# 2005                 0.36             0.95               3
# 2006                 0.54             0.37               2
# 2007                 0.99             0.91               5
# 2008                 0.50             0.75               6
# 2009                 0.74             0.64               4
# 2010                 0.56             0.58               4
# 2011                 0.34             0.39               2
# 2012                 0.48             0.94               5
# 2013                 0.73             0.62               3
# 2014                 0.59             0.87               3
# ...

# %%
len(retained)
# Out:
# 11428

# %%
ps=df.groupby('left').mean()

# %%
ps
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %% [markdown]
# # so from above we can see
# 1)Employee leaving the firm has satisfaction level of 0.44 vs the employee working in the firm
# 2)Average monthly hours of employee who left is 207 compared to that of employee who didnt left 199
# 3)Promotion_last_five years is more for employees who reatined

# %%
#2)bar chart showing impact of employee salaries on retention

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
df1=df[df.left==1]

# %%
df1
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2001                 0.82             0.67               2
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2004                 0.49             0.60               3
# 2005                 0.36             0.95               3
# 2006                 0.54             0.37               2
# 2007                 0.99             0.91               5
# 2008                 0.50             0.75               6
# 2009                 0.74             0.64               4
# 2010                 0.56             0.58               4
# 2011                 0.34             0.39               2
# 2012                 0.48             0.94               5
# 2013                 0.73             0.62               3
# 2014                 0.59             0.87               3
# ...

# %%
#df1['salary'].value_counts().plot(kind="bar",color="g",figsize=[7,8])

pd.crosstab(df.salary,df.left).plot(kind="bar")

# %%
df1['salary'].value_counts().plot(kind="bar",color="g",figsize=[7,8])

# %%
from above graph it is clear that employee with high salary are less likely to leave the company

# %% [markdown]
# #Bar chart betwen betwwen department and employee retention

# %%
pd.crosstab(df.Department,df.left).plot(kind="bar")

# %%
from sklearn.linear_model import LogisticRegression

# %%
df2=df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]

# %% [markdown]
# ##

# %%
df2.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low

# %%
dummy=pd.get_dummies(df2.salary)

# %%
dummy.head()
# Out:
#    high  low  medium
# 0     0    1       0
# 1     0    0       1
# 2     0    0       1
# 3     0    1       0
# 4     0    1       0

# %%
merge=pd.concat([df2,dummy],axis="columns")

# %%
merge.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary  \
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low
#
#    high  low  medium
# 0     0    1       0
# 1     0    0       1
# 2     0    0       1
# 3     0    1       0
# 4     0    1       0

# %%
merge=merge.drop('salary',axis="columns")

# %%
merge
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  high  \
# 0                    0.38                   157                      0     0
# 1                    0.80                   262                      0     0
# 2                    0.11                   272                      0     0
# 3                    0.72                   223                      0     0
# 4                    0.37                   159                      0     0
# 5                    0.41                   153                      0     0
# 6                    0.10                   247                      0     0
# 7                    0.92                   259                      0     0
# 8                    0.89                   224                      0     0
# 9                    0.42                   142                      0     0
# 10                   0.45                   135                      0     0
# ...

# %%
y=df.left

# %%
model=LogisticRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(merge,y,test_size=0.8)

# %%
len(X_test)
# Out:
# 12000

# %%
len(X_train)
# Out:
# 2999

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(X_test,Y_test)
# Out:
# 0.7838333333333334
